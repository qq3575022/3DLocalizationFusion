# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Demo

# %%
std = pd.read_csv('../Data/0304IMU/whole/1.csv', index_col = None, header = None)

std[0]=(1.0*(std[0] - std[0][0]) /1000000000).astype('float');

time = std[0].values

# %%
std_acc = std[std[1]==' ACC_UN']
acc_t = std_acc[0]
accx  = std_acc[2]
accy  = std_acc[3]
accz  = std_acc[4]

# %%
accT1 = loadmat('Filtered/1/accT.mat')['accT']
accx1 = loadmat('Filtered/1/accx.mat')['accx']
accy1 = loadmat('Filtered/1/accy.mat')['accy']
accz1 = loadmat('Filtered/1/accz.mat')['accz']

# %%
accT2 = loadmat('Filtered/2first/accT.mat')['accT']
accx2 = loadmat('Filtered/2first/accx.mat')['accx']
accy2 = loadmat('Filtered/2first/accy.mat')['accy']
accz2 = loadmat('Filtered/2first/accz.mat')['accz']

# %%
accT2s = loadmat('Filtered/2second/accT.mat')['accT']
accx2s = loadmat('Filtered/2second/accx.mat')['accx']
accy2s = loadmat('Filtered/2second/accy.mat')['accy']
accz2s = loadmat('Filtered/2second/accz.mat')['accz']

# %%
accT3 = loadmat('Filtered/3/accT.mat')['accT']
accx3 = loadmat('Filtered/3/accx.mat')['accx']
accy3 = loadmat('Filtered/3/accy.mat')['accy']
accz3 = loadmat('Filtered/3/accz.mat')['accz']

# %%
plt.figure(figsize=(40,25))

plt.subplot(511), plt.plot(accT1[7500:-4000], accx1[9500:-2000]), plt.title('Acceleration x Meas1', fontsize=30)
plt.ylim([0.2, 0.8]), plt.ylabel('Acceleration (m/s^2)', fontsize=20), plt.xlim([15,120])

plt.subplot(512), plt.plot(accT2s[7585:-3300], accx2[1500:-1500]), plt.title('Acceleration x Meas2', fontsize=30)
plt.ylim([0.2, 0.8]), plt.ylabel('Acceleration (m/s^2)', fontsize=20), plt.xlim([15,120])

plt.subplot(513),plt.plot(accT2s[7000:-3398], accx2s[8898:-1500]),plt.ylim([0,1]), plt.title('Acceleration x Meas3', fontsize=30)
plt.ylim([0.2, 0.8]), plt.ylabel('Acceleration (m/s^2)', fontsize=20), plt.xlim([15,120])

plt.subplot(514),plt.plot(accT3[7000:], accx3[7000:]), plt.title('Acceleration x Meas4', fontsize=30)
plt.ylim([0.2, 0.8]), plt.ylabel('Acceleration (m/s^2)', fontsize=20), plt.xlim([15,120])

plt.subplot(515), plt.plot(acc_t[7500:-4000], accx[9500:-2000]), plt.title('Raw Measurment Data', fontsize=30)
plt.ylim([0.2, 0.8]), plt.ylabel('Acceleration (m/s^2)', fontsize=20), plt.xlim([15,120])
# Out:
# ((0.2, 0.8), Text(0,0.5,u'Acceleration (m/s^2)'), (15, 120))

# %%
plt.figure(figsize=(40,25))

plt.subplot(511), plt.plot(accT1[7598:-500], accy1[7598:-500]), plt.title('Acceleration y Meas1', fontsize=30)
plt.ylim([9.72, 9.875]), plt.ylabel('Acceleration (m/s^2)', fontsize=20), plt.xlim([15,120])

plt.subplot(512), plt.plot(accT2s[7565:-480], accy2[80:-80]), plt.title('Acceleration y Meas2', fontsize=30)
plt.ylim([9.72, 9.875]), plt.ylabel('Acceleration (m/s^2)', fontsize=20), plt.xlim([15,120])

plt.subplot(513),plt.plot(accT2s[7598:-3898], accy2s[7098:-4398]), plt.title('Acceleration y Meas3', fontsize=30)
plt.ylim([9.72, 9.875]), plt.ylabel('Acceleration (m/s^2)', fontsize=20), plt.xlim([15,120])

plt.subplot(514),plt.plot(accT3[7598:-1500], accy3[5598:-3500]), plt.title('Acceleration y Meas4', fontsize=30)
plt.ylim([9.72, 9.875]), plt.ylabel('Acceleration (m/s^2)', fontsize=20), plt.xlim([15,120])

plt.subplot(515), plt.plot(acc_t[7598:-500], accy[7598:-500]), plt.title('Raw Measurment Data', fontsize=30)
plt.ylim([9.5, 10]), plt.ylabel('Acceleration (m/s^2)', fontsize=20), plt.xlim([15,120])

#plt.ylim([0.2, 0.8]), plt.ylabel('Acceleration (m/s^2)', fontsize=20)
# Out:
# ((9.5, 10), Text(0,0.5,u'Acceleration (m/s^2)'), (15, 120))

# %%
plt.figure(figsize=(40,25))

plt.subplot(511), plt.plot(accT1[7500:-4000], accz1[9500:-2000]), plt.title('Acceleration z Meas1', fontsize=30)
plt.ylim([-0.7, -0.4]), plt.ylabel('Acceleration (m/s^2)', fontsize=20), plt.xlim([15,120])

plt.subplot(512), plt.plot(accT2s[7585:-3300], accz2[1500:-1500]), plt.title('Acceleration z Meas2', fontsize=30)
plt.ylim([-0.7, -0.4]), plt.ylabel('Acceleration (m/s^2)', fontsize=20), plt.xlim([15,120])

plt.subplot(513),plt.plot(accT2s[7000:-3398], accz2s[8898:-1500]),plt.title('Acceleration z Meas3', fontsize=30)
plt.ylim([-0.7, -0.4]), plt.ylabel('Acceleration (m/s^2)', fontsize=20), plt.xlim([15,120])

plt.subplot(514),plt.plot(accT3[7000:], accz3[7000:]), plt.title('Acceleration z Meas4', fontsize=30)
plt.ylim([-0.8, -0.45]), plt.ylabel('Acceleration (m/s^2)', fontsize=20), plt.xlim([15,120])

plt.subplot(515), plt.plot(acc_t[7500:-4000], accz[9500:-2000]), plt.title('Raw Measurment Data', fontsize=30)
plt.ylim([-0.8, -0.3]), plt.ylabel('Acceleration (m/s^2)', fontsize=20), plt.xlim([15,120])

#plt.ylim([0.2, 0.8]), plt.ylabel('Acceleration (m/s^2)', fontsize=20), plt.xlim([15,120])
# Out:
# ((-0.8, -0.3), Text(0,0.5,u'Acceleration (m/s^2)'), (15, 120))
