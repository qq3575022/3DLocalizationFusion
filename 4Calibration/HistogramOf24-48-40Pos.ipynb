# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# !pwd
# Out:
# /Users/Joanna/Documents/PhD/Graduation/3DDissertation/1Calibration

# %%
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "sans-serif",
    "font.sans-serif": ["Helvetica"]})

# %%
plt.figure(figsize = (15,15))
plt.subplot(331)
plt.hist([0.0308, 0.0828, 0.0466, 0.0016, 0.0726, 0.0329, 0.0704], bins=5)
plt.hist([0.0539, 0.1094, 0.0893, 0.0912, 0.0642, 0.1323, 0.1254], bins=5)
plt.hist([0.0662, 0.0575, 0.0640, 0.0779, 0.0623, 0.0691], bins=5)
plt.xlim([0, 0.24])
plt.ylabel('count')
plt.legend(['24 pos','48 pos','modified 40 pos'])
plt.title(r'parameter $- \alpha_{yz}$')

plt.subplot(332)
plt.hist([0.0247, 0.0505, 0.0680, 0.0942, 0.1060, 0.0237], bins=5)
plt.hist([0.0240, 0.0983, 0.0633, 0.0868, 0.0612, 0.0442], bins=5)
plt.hist([0.0009717, 0.0075, 0.0112, -0.0013, 0.0055, 0.0058], bins=5)
plt.xlim([0, 0.24])
plt.legend(['24 pos','48 pos','modified 40 pos'])
plt.title(r'parameter $\alpha_{zy}$')

plt.subplot(333)
plt.hist([-0.0394, -0.0489, -0.0370, -0.0502, -0.0383, -0.0377, -0.0366], bins=5)
plt.hist([-0.0441, -0.0022, -0.0649, -0.0593, -0.0673, -0.0699, -0.0539], bins=5)
plt.hist([-0.0062, -0.0125, -0.0055, -0.0045, -0.0041, -0.0054], bins=5)
plt.xlim([-0.24, 0])
plt.legend(['24 pos','48 pos','modified 40 pos'])
plt.title(r'parameter $- \alpha_{zx}$')

plt.subplot(334)
plt.hist([1.0003, 0.9875, 0.9741, 0.9768, 0.9991, 0.9717, 0.9914], bins=5)
plt.hist([1.0009, 0.9790, 0.9831, 0.9789, 0.9816, 0.9897, 0.9954], bins=5)
plt.hist([0.9946, 0.9923, 0.9914, 0.9953, 0.9944, 0.9941], bins=5)
plt.xlim([0.85, 1.13])
plt.ylabel('count')
plt.legend(['24 pos','48 pos','modified 40 pos'])
plt.title(r'parameter $S_{x}^a$')

plt.subplot(335)
plt.hist([1.0009, 0.9964, 1.0013, 0.9999, 0.9969, 0.9988, 0.9995], bins=5)
plt.hist([0.9990, 0.9902, 0.9964, 0.9965, 0.9980, 0.9934, 0.9951], bins=5)

plt.hist([0.9980, 0.9982, 0.9978, 0.9983, 0.9999, 0.9986], bins=5)
plt.xlim([0.85, 1.13])
plt.legend(['24 pos','48 pos','modified 40 pos'])
plt.title(r'parameter $S_{y}^a$')

plt.subplot(336)
plt.hist([0.9897, 0.9845, 0.9772, 0.9774, 0.9899, 0.9703, 0.9828], bins=5)
plt.hist([0.9963, 0.9745, 0.9784, 0.9742, 0.9837, 0.9808, 0.9879], bins=5)

plt.hist([0.9892, 0.9883, 0.9867, 0.9895, 0.9880, 0.9880], bins=3)
plt.xlim([0.85, 1.13])
plt.legend(['24 pos','48 pos','modified 40 pos'])
plt.title(r'parameter $S_{z}^a$')

plt.subplot(337)
plt.hist([0.2195, 0.1879, 0.1135, 0.1581, 0.1774, 0.1171, 0.0807], bins=5)
plt.hist([0.2355, 0.1501, 0.1384, 0.1152, 0.1516, 0.2208, 0.2143], bins=5)

plt.hist([0.1853, 0.1728, 0.1719, 0.1887, 0.1739, 0.1731], bins=5)
plt.xlim([0, 0.24])
plt.xlabel('value')
plt.ylabel('count')
plt.legend(['24 pos','48 pos','modified 40 pos'])
plt.title(r'parameter $b_{x}^a$')

plt.subplot(338)
plt.hist([0.0350, 0.0555, 0.0912, 0.0612, 0.0576, 0.0744, 0.0807], bins=5)
plt.hist([0.0755, 0.0155, 0.1137, 0.0797, 0.0862, 0.0463, 0.0968], bins=5)

plt.hist([0.0058, 0.0394, 0.0140, 0.0147, 0.0071, 0.0198], bins=5)
plt.xlim([0, 0.24])
plt.xlabel('value')
plt.legend(['24 pos','48 pos','modified 40 pos'])
plt.title(r'parameter $b_{y}^a$')

plt.subplot(339)
plt.hist([-0.3251, -0.2620, -0.2755, -0.2859, -0.2945, -0.2310, -0.3010], bins=5)
plt.hist([-0.3106, -0.2987, -0.2372, -0.2553, -0.2629, -0.3217, -0.3184], bins=5)

plt.hist([-0.2787, -0.2761, -0.2818, -0.3036, -0.2999, -0.2947], bins=4)
plt.xlim([-0.45, -0.1])
plt.xlabel('value')
plt.legend(['24 pos','48 pos','modified 40 pos'])
plt.title(r'parameter $b_{z}^a$')
# Out:
# Text(0.5,1,u'parameter $b_{z}^a$')

# %%
plt.hist([0.0247, 0.0505, 0.0680, 0.0942, 0.1060, 0.0237], bins=5)
plt.hist([0.0240, 0.0983, 0.0633, 0.0868, 0.0612, 0.0442], bins=5)
plt.xlim([0, 0.24])
plt.legend(['24 pos','48 pos'])
plt.title(r'parameter $\alpha_{zy}$')
# Out:
# Text(0.5,1,u'parameter $\\alpha_{zy}$')

# %%
plt.hist([-0.0394, -0.0489, -0.0370, -0.0502, -0.0383, -0.0377, -0.0366], bins=5)
plt.hist([-0.0441, -0.0022, -0.0649, -0.0593, -0.0673, -0.0699, -0.0539], bins=5)
plt.xlim([-0.24, 0])
plt.legend(['24 pos','48 pos'])
plt.title(r'parameter $- \alpha_{zx}$')
# Out:
# Text(0.5,1,u'parameter $- \\alpha_{zx}$')

# %%
plt.hist([1.0003, 0.9875, 0.9741, 0.9768, 0.9991, 0.9717, 0.9914], bins=5)
plt.hist([1.0009, 0.9790, 0.9831, 0.9789, 0.9816, 0.9897, 0.9954], bins=5)
plt.xlim([0.85, 1.13])
plt.legend(['24 pos','48 pos'])
plt.title(r'parameter $S_{x}^a$')
# Out:
# Text(0.5,1,u'parameter $S_{x}^a$')

# %%
plt.hist([1.0009, 0.9964, 1.0013, 0.9999, 0.9969, 0.9988, 0.9995], bins=5)
plt.hist([0.9990, 0.9902, 0.9964, 0.9965, 0.9980, 0.9934, 0.9951], bins=5)
plt.xlim([0.85, 1.13])
plt.legend(['24 pos','48 pos'])
plt.title(r'parameter $S_{y}^a$')
# Out:
# Text(0.5,1,u'parameter $S_{y}^a$')

# %%
plt.hist([0.9897, 0.9845, 0.9772, 0.9774, 0.9899, 0.9703, 0.9828], bins=5)
plt.hist([0.9963, 0.9745, 0.9784, 0.9742, 0.9837, 0.9808, 0.9879], bins=5)
plt.xlim([0.85, 1.13])
plt.legend(['24 pos','48 pos'])
plt.title(r'parameter $S_{z}^a$')
# Out:
# Text(0.5,1,u'parameter $S_{z}^a$')

# %%
plt.hist([0.2195, 0.1879, 0.1135, 0.1581, 0.1774, 0.1171, 0.0807], bins=5)
plt.hist([0.2355, 0.1501, 0.1384, 0.1152, 0.1516, 0.2208, 0.2143], bins=5)
plt.xlim([0, 0.24])
plt.legend(['24 pos','48 pos'])
plt.title(r'parameter $b_{x}^a$')
# Out:
# Text(0.5,1,u'parameter $b_{x}^a$')

# %%
plt.hist([0.0350, 0.0555, 0.0912, 0.0612, 0.0576, 0.0744, 0.0807], bins=5)
plt.hist([0.0755, 0.0155, 0.1137, 0.0797, 0.0862, 0.0463, 0.0968], bins=5)
plt.xlim([0, 0.24])
plt.legend(['24 pos','48 pos'])
plt.title(r'parameter $b_{y}^a$')
# Out:
# Text(0.5,1,u'parameter $b_{y}^a$')

# %%
plt.hist([-0.3251, -0.2620, -0.2755, -0.2859, -0.2945, -0.2310, -0.3010], bins=5)
plt.hist([-0.3106, -0.2987, -0.2372, -0.2553, -0.2629, -0.3217, -0.3184], bins=5)
plt.xlim([-0.45, -0.1])
plt.legend(['24 pos','48 pos'])
plt.title(r'parameter $b_{z}^a$')
# Out:
# Text(0.5,1,u'parameter $b_{z}^a$')
